# %%
from bs4 import BeautifulSoup
from httpx import AsyncClient
import re
import json
import pandas as pd

# %%
async def get_soup(url: str, client: AsyncClient) -> BeautifulSoup:
    resp = await client.get(url)
    resp.raise_for_status()
    html = resp.text
    return BeautifulSoup(html, 'html.parser')

# %%
roast_map = {
    'torr:Moyen': 'Medium'
}
def translate_roast(tags: list[str]) -> str:
    try:
        torr = next(filter(lambda tag: tag[0:4] == 'torr', tags))
        return roast_map.get(torr, torr)
    except StopIteration:
        return 'unknown'
    
def to_grams(weight: str) -> int:
    m = re.match('^(\d+)\s?(k?g)', weight)
    if not m:
        return None
    val = int(m[1])
    if m[2] == 'g':
        return val
    else:
        return 1000 * val


def to_dataframe(data: dict) -> pd.DataFrame:
    df = pd.DataFrame(data['variants'])
    df.drop(df.query('not available').index, inplace=True)
    df['grams'] = df.option1.apply(to_grams)
    df.dropna(subset='grams', inplace=True)
    df['price_per_gram'] = df['price'] / df['grams']
    df['name'] = data['title']
    df['description'] = BeautifulSoup(data['description'], 'html.parser').text
    df['roast'] = translate_roast(data['tags'])
    return df[['name', 'grams', 'price', 'price_per_gram', 'description']]

# %%
async with AsyncClient(base_url='https://www.brulerieduquai.com/en/collections/cafe') as client:
    dfs = []
    main_page = await get_soup('/', client)
    coffees = [a['href'].split('/')[-1] for a in main_page.find_all('a') 
               if a['href'].startswith('/en/collections/cafe/products/')][::2]
    for coffee in coffees:
        print(f"Processing {coffee}...")
        coffeesoup = await get_soup(f'/products/{coffee}', client)
        s = coffeesoup.find_all('script.bold-subscriptions-platform-script')
        s = [s for s in coffeesoup.find_all('script') if 'sswApp.product =' in s.text][0]
        ss: str = [ss for ss in s.text.split('\n') if 'sswApp.product' in ss][0]
        data = json.loads(ss[ss.index('=')+1:-1])
        df = to_dataframe(data)
        if not df.empty:
            dfs.append(df)

df = pd.concat(dfs).reset_index().drop(columns='index')
df
# Out:
# Processing calendrier-avent-cafe...
# Processing blue-mountain...
# Processing geisha-la-esmeralda...
# Processing barbosa-90...
# Processing el-injerto-90...
# Processing pb-barbosa...
# Processing legendary-geisha...
# Processing cafe-apero-espresso...
# Processing yemenia-khalid-kulaib...
# Processing nyeri-kamoini...
# Processing cafe-bresil-cerrado...
# Processing bad-boy-espresso...
# Processing bad-girl-espresso...
# Processing yirgacheffe...
# Processing harrar...
# Processing cafe-assemblage-crema-special...
#                                    name  grams  price  price_per_gram  \
# 0   Typica Jamaïca Blue Mountain Coffee    200   5000       25.000000
# 1     Geisha Panama La Esmeralda Coffee    200   5000       25.000000
# 2            Brazil Coffee - Barbosa 90    200   8600       43.000000
# 3             Brazil Coffee PB. Barbosa    200   2000       10.000000
# 4   Guatemala Coffee - Legendary Geisha    200   5999       29.995000
# 5                          Apéro Coffee    340   1850        5.441176
# 6                          Apéro Coffee   2000   9206        4.603000
# 7               Brazil Coffee - Cerrado    340   1850        5.441176
# 8               Brazil Coffee - Cerrado   2000   9206        4.603000
# 9               Bad Boy Espresso Coffee    340   1850        5.441176
# 10              Bad Boy Espresso Coffee   2000   9206        4.603000
# 11             Bad Girl Espresso Coffee    340   1850        5.441176
# 12             Bad Girl Espresso Coffee   2000   9206        4.603000
# 13        Ethiopia Coffee - Yirgacheffe    340   1850        5.441176
# 14        Ethiopia Coffee - Yirgacheffe   2000   9206        4.603000
# 15             Ethiopia Coffee - Harrar    340   2145        6.308824
# 16             Ethiopia Coffee - Harrar   2000  10899        5.449500
# 17                 Créma Spécial Coffee    340   1485        4.367647
# 18                 Créma Spécial Coffee   1000   3700        3.700000
# 19                 Créma Spécial Coffee   2000   6729        3.364500
#
#                                           description
# 0   Clifton Mount Estate is located 1300m on the e...
# 1   \n Harvest 2020 - Limited quantityComing from ...
# 2   This coffee was produced by the one and only D...
# 3   The producer and owner of DBarbosa Coffee, Vit...
# 4   This coffee is produced by El Injerto, one of ...
# 5   This blend is inspired by fruity liqueurs and ...
# 6   This blend is inspired by fruity liqueurs and ...
# 7   Here is a coffee from the plantation of the Ba...
# 8   Here is a coffee from the plantation of the Ba...
# 9   This blend is optimized for a comforting, roun...
# 10  This blend is optimized for a comforting, roun...
# 11  \nThis blend is optimized for an invigorating,...
# 12  \nThis blend is optimized for an invigorating,...
# 13  \n\n\nThe Yirgacheffe area is located in the s...
# 14  \n\n\nThe Yirgacheffe area is located in the s...
# 15  Harrar is located in the highlands of eastern ...
# 16  Harrar is located in the highlands of eastern ...
# 17  Here is a blend inspired by a typical Italian ...
# 18  Here is a blend inspired by a typical Italian ...
# 19  Here is a blend inspired by a typical Italian ...

# %%
df.drop(columns='index')
# Out:
#                                    name  grams  price  price_per_gram  \
# 0   Typica Jamaïca Blue Mountain Coffee    200   5000       25.000000
# 1     Geisha Panama La Esmeralda Coffee    200   5000       25.000000
# 2            Brazil Coffee - Barbosa 90    200   8600       43.000000
# 3             Brazil Coffee PB. Barbosa    200   2000       10.000000
# 4   Guatemala Coffee - Legendary Geisha    200   5999       29.995000
# 5                          Apéro Coffee    340   1850        5.441176
# 6                          Apéro Coffee   2000   9206        4.603000
# 7               Brazil Coffee - Cerrado    340   1850        5.441176
# 8               Brazil Coffee - Cerrado   2000   9206        4.603000
# 9               Bad Boy Espresso Coffee    340   1850        5.441176
# 10              Bad Boy Espresso Coffee   2000   9206        4.603000
# 11             Bad Girl Espresso Coffee    340   1850        5.441176
# 12             Bad Girl Espresso Coffee   2000   9206        4.603000
# 13        Ethiopia Coffee - Yirgacheffe    340   1850        5.441176
# 14        Ethiopia Coffee - Yirgacheffe   2000   9206        4.603000
# 15             Ethiopia Coffee - Harrar    340   2145        6.308824
# 16             Ethiopia Coffee - Harrar   2000  10899        5.449500
# 17                 Créma Spécial Coffee    340   1485        4.367647
# 18                 Créma Spécial Coffee   1000   3700        3.700000
# 19                 Créma Spécial Coffee   2000   6729        3.364500
#
#                                           description
# 0   Clifton Mount Estate is located 1300m on the e...
# 1   \n Harvest 2020 - Limited quantityComing from ...
# 2   This coffee was produced by the one and only D...
# 3   The producer and owner of DBarbosa Coffee, Vit...
# 4   This coffee is produced by El Injerto, one of ...
# 5   This blend is inspired by fruity liqueurs and ...
# 6   This blend is inspired by fruity liqueurs and ...
# 7   Here is a coffee from the plantation of the Ba...
# 8   Here is a coffee from the plantation of the Ba...
# 9   This blend is optimized for a comforting, roun...
# 10  This blend is optimized for a comforting, roun...
# 11  \nThis blend is optimized for an invigorating,...
# 12  \nThis blend is optimized for an invigorating,...
# 13  \n\n\nThe Yirgacheffe area is located in the s...
# 14  \n\n\nThe Yirgacheffe area is located in the s...
# 15  Harrar is located in the highlands of eastern ...
# 16  Harrar is located in the highlands of eastern ...
# 17  Here is a blend inspired by a typical Italian ...
# 18  Here is a blend inspired by a typical Italian ...
# 19  Here is a blend inspired by a typical Italian ...

# %%
roast_map = {
    'torr:Moyen': 'Medium'
}

def to_dataframe(data: dict) -> pd.DataFrame:
    df = pd.DataFrame(data['variants'])
    df['name'] = data['title']
    df['description'] = data['description']
    df['roast'] = roast_map.get(next(filter(lambda tag: tag[0:4] == 'torr', data['tags'])))
    df['grams'] = df.option1.apply(lambda weight: int(weight[0:-1]) if re.match('\d+\s?g', weight) else 1000*int(weight[0:-2]) )
    df['price_per_gram'] = df['price']/df['grams']
    return df[['name', 'grams', 'price', 'price_per_gram', 'description']]
# Out:
#                    name  grams  price  price_per_gram  \
# 0  Créma Spécial Coffee    340   1485        4.367647
# 1  Créma Spécial Coffee   1000   3700        3.700000
# 2  Créma Spécial Coffee   2000   6729        3.364500
#
#                                          description
# 0  <div>Here is a blend inspired by a typical Ita...
# 1  <div>Here is a blend inspired by a typical Ita...
# 2  <div>Here is a blend inspired by a typical Ita...

# %%
df
# Out:
#                id title option1 option2 option3    sku  requires_shipping  \
# 0       212217933  340g    340g    None    None  10011               True
# 1  44089131335933   1kg     1kg    None    None  10014               True
# 2       212217937   2kg     2kg    None    None  10012               True
#
#    taxable featured_image  available  ... weight compare_at_price  \
# 0    False           None       True  ...    356             None
# 1    False           None       True  ...    356             None
# 2    False           None       True  ...   2042             None
#
#   inventory_quantity  inventory_management  inventory_policy       barcode  \
# 0                  0               shopify          continue  877609000034
# 1                  1               shopify          continue
# 2                  0               shopify          continue  692065520007
#
#    requires_selling_plan                           selling_plan_allocations  \
# 0                  False  [{'price_adjustments': [{'position': 1, 'price...
# 1                  False  [{'price_adjustments': [{'position': 1, 'price...
# 2                  False  [{'price_adjustments': [{'position': 1, 'price...
#
#   grams price_per_gram
# 0   340       4.367647
# 1  1000       3.700000
# 2  2000       3.364500
#
# [3 rows x 24 columns]
